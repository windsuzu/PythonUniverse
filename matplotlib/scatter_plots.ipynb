# %% [markdown]
# # Scattor Plots

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
temperature = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2, 30]

ice_cream_sales = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408, 1403]

# %%
plt.scatter(temperature, ice_cream_sales)
plt.xlabel("temperature")
plt.ylabel("ice cream price")
# Out:
# Text(0, 0.5, 'ice cream price')

# %% [markdown]
# ## Log Scale (Work with outliers)

# %%
plt.scatter(temperature, ice_cream_sales)
plt.xlabel("temperature")
plt.ylabel("ice cream price")

plt.yscale("log")  # use log scale on y-axis to handle outliners

# %% [markdown]
# ## Size

# %%
plt.scatter(temperature, ice_cream_sales, 
            s=ice_cream_sales)  # set the size according to the prices of the ice cream
plt.xlabel("temperature")
plt.ylabel("ice cream price")
# Out:
# Text(0, 0.5, 'ice cream price')

# %% [markdown]
# ## Coloring and Colorbar

# %%
colors = np.array(ice_cream_sales) / np.linalg.norm(ice_cream_sales)
colors
# Out:
# array([0.10635703, 0.16077226, 0.09151652, 0.16423505, 0.20084165,
#        0.25822498, 0.20380976, 0.3037359 , 0.26910803, 0.20826191,
#        0.22013433, 0.20183102, 0.69404148])

# %%
plt.scatter(temperature, ice_cream_sales, 
            s=ice_cream_sales,
            c=colors,  # set the colors according to the prices of the ice cream
            cmap="Greens",  # preferred color type
            edgecolor="black",  # the edge color of points
            lw=0.5,  # the edge width of points
            alpha=.75,
            )

plt.xlabel("temperature")
plt.ylabel("ice cream price")
plt.yscale("log")

cbar = plt.colorbar()
cbar.set_label("Expensive")
plt.tight_layout()
plt.savefig("../assets/matplotlib/scattor_plots.jpg")

# %% [markdown]
# # Reference
#
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html#matplotlib.pyplot.scatter
# - https://www.youtube.com/watch?v=zZZ_RCwp49g
